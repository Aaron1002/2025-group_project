# %% [markdown]
# `eTag 配對路徑動態資訊(v2.0)`、`eTag 配對路徑靜態資訊(v2.0)`

# %%
path = {'etag_move' : r"D:\data\eTag 配對路徑動態資訊(v2.0).csv", 
        'etag_static' : r"D:\data\eTag 配對路徑靜態資訊(v2.0).csv"
        }

# %%
import pandas as pd
import dask.dataframe as dd

# %%
from dask.diagnostics import ProgressBar

pbar = ProgressBar()
pbar.register()  # 註冊進度條

# %% [markdown]
# # view `eTag 配對路徑動態資訊(v2.0)`

# %%
# df_etag_move = pd.read_csv(path['etag_move'], encoding='utf-8')
df_etag_move = dd.read_csv(path['etag_move'], encoding='utf-8')

# %% [markdown]
# ## 檢視欄位名稱

# %%
df_etag_move.columns
# Out:
# Index(['timestamp', 'ETagPairID', 'StartETagStatus', 'EndETagStatus',
#        'StartTime', 'EndTime', 'DataCollectTime', 'VehicleType', 'TravelTime',
#        'StandardDeviation', 'SpaceMeanSpeed', 'VehicleCount'],
#       dtype='object')

# %% [markdown]
# ## 前5筆資料

# %%
df_etag_move.head()
# Out:
#              timestamp         ETagPairID  StartETagStatus  EndETagStatus  \
# 0  2024-01-01 00:00:00  03F4232S-03F4263S                0              0
# 1  2024-01-01 00:00:00  03F4232S-03F4263S                0              0
# 2  2024-01-01 00:00:00  03F4232S-03F4263S                0              0
# 3  2024-01-01 00:00:00  03F4232S-03F4263S                0              0
# 4  2024-01-01 00:00:00  03F4232S-03F4263S                0              0
#
#                    StartTime                    EndTime  \
# 0  2023-12-31T23:30:00+08:00  2023-12-31T23:35:00+08:00
# 1  2023-12-31T23:30:00+08:00  2023-12-31T23:35:00+08:00
# 2  2023-12-31T23:30:00+08:00  2023-12-31T23:35:00+08:00
# 3  2023-12-31T23:30:00+08:00  2023-12-31T23:35:00+08:00
# 4  2023-12-31T23:30:00+08:00  2023-12-31T23:35:00+08:00
#
#              DataCollectTime  VehicleType  TravelTime  StandardDeviation  \
# 0  2023-12-31T23:35:00+08:00           31          97                  0
# 1  2023-12-31T23:35:00+08:00           32         100                  0
# 2  2023-12-31T23:35:00+08:00           41         114                  0
# 3  2023-12-31T23:35:00+08:00           42           0                  0
# 4  2023-12-31T23:35:00+08:00            5           0                  0
#
#    SpaceMeanSpeed  VehicleCount
# 0             113            18
# 1             111             7
# 2              97             1
# 3               0             0
# 4               0             0

# %% [markdown]
# ## 資料比數(有多少row)

# %%
df_etag_move.shape[0].compute(progress=True)
# Out:
# [########################################] | 100% Completed | 362.67 s
# 181381535

# %% [markdown]
# ## 缺失值

# %% [markdown]
# ### 各欄位缺失值統計

# %%
df_etag_move.isna().sum().compute(progress=True)
# Out:
# [########################################] | 100% Completed | 541.75 s
# timestamp            0
# ETagPairID           0
# StartETagStatus      0
# EndETagStatus        0
# StartTime            0
# EndTime              0
# DataCollectTime      0
# VehicleType          0
# TravelTime           0
# StandardDeviation    0
# SpaceMeanSpeed       0
# VehicleCount         0
# dtype: int64

# %% [markdown]
# ### 整筆資料缺失(某個時間無資料)

# %%
pass

# %% [markdown]
# ## 特定欄位分析

# %% [markdown]
# ### 車種代碼

# %%
df_etag_move['VehicleType'].value_counts().compute(progress=True)
# Out:
# [########################################] | 100% Completed | 348.23 s
# VehicleType
# 41    36276307
# 31    36276307
# 32    36276307
# 42    36276307
# 5     36276307
# Name: count, dtype: int64

# %% [markdown]
# ### StartETagStatus

# %%
df_etag_move['StartETagStatus'].value_counts().compute(progress=True)
# Out:
# [########################################] | 100% Completed | 452.53 s
# StartETagStatus
# 0    181381535
# Name: count, dtype: int64

# %% [markdown]
# ### EndETagStatus

# %%
df_etag_move['EndETagStatus'].value_counts().compute(progress=True)
# Out:
# [########################################] | 100% Completed | 460.08 s
# EndETagStatus
# 0    181381535
# Name: count, dtype: int64

# %% [markdown]
# # view `eTag 配對路徑靜態資訊(v2.0)`

# %%
df_etag_static = pd.read_csv(path['etag_static'], encoding='utf-8')

# %% [markdown]
# ## 前5筆資料

# %%
df_etag_static.head()
# Out:
#     timestamp         ETagPairID StartETagGantryID EndETagGantryID  \
# 0  2024-01-01  03F4232S-03F4263S          03F4232S        03F4263S
# 1  2024-01-01  01H0608N-01H0579N          01H0608N        01H0579N
# 2  2024-01-01  03F1022S-03F1051S          03F1022S        03F1051S
# 3  2024-01-01  03F0116S-03F0136S          03F0116S        03F0136S
# 4  2024-01-01  03F3854S-03F3916S          03F3854S        03F3916S
#
#   Description  Distance     StartLinkID       EndLinkID  \
# 0       崁頂-南州      3.08  0000300042300T  0000300042600T
# 1      校前路-中壢      2.86  00001B0106020H  00001B0105700H
# 2     新竹系統-茄苳      2.81  0000300010200J  0000300010500O
# 3   汐止系統-新台五路      1.92  0000300001100F  0000300001360F
# 4     燕巢系統-九如      6.17  0000300038500E  0000300039150T
#
#                                             Geometry  \
# 0  LINESTRING(120.52478 22.50763,120.52480 22.506...
# 1  LINESTRING(121.21152 24.96581,121.21181 24.966...
# 2  LINESTRING(120.97318 24.75786,120.97179 24.758...
# 3  LINESTRING(121.64373 25.06680,121.64332 25.065...
# 4  LINESTRING(120.43613 22.77163,120.43666 22.771...
#
#                   UpdateTime
# 0  2024-01-01T00:00:00+08:00
# 1  2024-01-01T00:00:00+08:00
# 2  2024-01-01T00:00:00+08:00
# 3  2024-01-01T00:00:00+08:00
# 4  2024-01-01T00:00:00+08:00

# %% [markdown]
# ## 缺失值

# %%
df_etag_static.isna().sum()
# Out:
# timestamp            0
# ETagPairID           0
# StartETagGantryID    0
# EndETagGantryID      0
# Description          0
# Distance             0
# StartLinkID          0
# EndLinkID            0
# Geometry             0
# UpdateTime           0
# dtype: int64

# %% [markdown]
# ## 檢視欄位

# %%
df_etag_static.columns
# Out:
# Index(['timestamp', 'ETagPairID', 'StartETagGantryID', 'EndETagGantryID',
#        'Description', 'Distance', 'StartLinkID', 'EndLinkID', 'Geometry',
#        'UpdateTime'],
#       dtype='object')

# %% [markdown]
# ## 檢視資料筆數(row數)

# %%
df_etag_static.shape[0]
# Out:
# 175136
